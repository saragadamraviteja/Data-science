# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# from nltk.book import *

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(type(text1))
# Out:
# <class 'nltk.text.Text'>

# %%
from nltk.corpus import brown

# %%
print(type(brown))
# Out:
# <class 'nltk.corpus.util.LazyCorpusLoader'>

# %%
brown.fileids()
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44',
#  'cb01',
#  'cb02',
#  'cb03',
#  'cb04',
#  'cb05',
#  'cb06',
#  'cb07',
#  'cb08',
#  'cb09',
#  'cb10',
#  'cb11',
#  'cb12',
#  'cb13',
#  'cb14',
#  'cb15',
#  'cb16',
#  'cb17',
#  'cb18',
#  'cb19',
#  'cb20',
#  'cb21',
#  'cb22',
#  'cb23',
#  'cb24',
#  'cb25',
#  'cb26',
#  'cb27',
#  'cc01',
#  'cc02',
#  'cc03',
#  'cc04',
#  'cc05',
#  'cc06',
#  'cc07',
#  'cc08',
#  'cc09',
#  'cc10',
#  'cc11',
#  'cc12',
#  'cc13',
#  'cc14',
#  'cc15',
#  'cc16',
#  'cc17',
#  'cd01',
#  'cd02',
# ...

# %%
brown.readme()
# Out:
# 'BROWN CORPUS\n\nA Standard Corpus of Present-Day Edited American\nEnglish, for use with Digital Computers.\n\nby W. N. Francis and H. Kucera (1964)\nDepartment of Linguistics, Brown University\nProvidence, Rhode Island, USA\n\nRevised 1971, Revised and Amplified 1979\n\nhttp://www.hit.uib.no/icame/brown/bcm.html\n\nDistributed with the permission of the copyright holder,\nredistribution permitted.\n'

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
temp = brown.words(categories='hobbies')

# %%
temp
# Out:
# ['Too', 'often', 'a', 'beginning', 'bodybuilder', ...]

# %%
# text1 = temp.split()
abstracts1 = nltk.Text(temp)

# %%
abstracts1.concordance('Too')
# Out:
# Displaying 25 of 58 matches:
#  Too often a beginning bodybuilder has to
# le weapons , but they also have their too little known limitations . Because of
# s a symphonic one . Yet no detail was too small to receive attention from this
# he support needed for such a result . Too many records seem to reduce a work of
#  sure sign that you are taking things too seriously and had better stop ! ! Or
# fitting . The order of fitting is not too important . However , we started with
#  load , pure and simple ; ; it's much too explosive for small edible game . It
# ike this gauge and type of scattergun too . Shotguns , '61 Although there were
# ulder Creek or at Santa Cruz . Gazing too long at the scenery could be tiring ,
# xt to sprinkle over coals if they are too hot , and to stop flames that arise f
# rigerator . Don't plan meals that are too complicated . Limit yourself to good
# grill permits you to toast the buns , too . Watch closely while browning them ,
# ...

# %%
from nltk.corpus import webtext

# %%
from nltk.corpus import inaugural

inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
f = open('tweets1.txt','r')
text = f.read()
text1 = text.split()
abstracts = nltk.Text(text1)

# %%
abstracts.concordance('luck')
abstracts.concordance('Too')
# Out:
# Displaying 2 of 2 matches:
#  Signal premiere. Lotsa buyers. Good luck gang listening to the pocast net@nit
# t I can throw farther than her. Good luck with that dude. Sure it will all be
# Displaying 5 of 5 matches:
# er that kids are being exposed to sex too soon? Download or subscribe to the In
#  of our days to rotate. That's crazy! Too bad it's so inhospitable. is wonderin
#  anymore! :D Chillen in west Spending too much time on the net! waking up in a
# ssues. Playing with widgets. Macs are too cool! on my way back from westchester
# oth hugs! Hotels without WiFi are all too disturbingly common. Worse is the hot

# %% [markdown]
# #  frequency distributions

# %%
fdist1 = FreqDist(text1)

# %%
print(fdist1)
# Out:
# <FreqDist with 4688 samples and 11102 outcomes>

# %%
fdist1.most_common(30)
# Out:
# [('to', 358),
#  ('the', 316),
#  ('a', 252),
#  ('for', 179),
#  ('and', 165),
#  ('I', 153),
#  ('on', 147),
#  ('of', 142),
#  ('my', 140),
#  ('in', 134),
#  ('is', 121),
#  ('url', 96),
#  ('at', 84),
#  ('with', 57),
#  ('that', 55),
#  ('from', 54),
#  ('it', 46),
#  ('up', 45),
#  ('are', 45),
#  ('about', 45),
#  ('new', 44),
#  ('just', 43),
#  ('out', 43),
#  ('this', 42),
#  ('-', 39),
#  ('be', 37),
#  ('twitter', 36),
#  ("I'm", 35),
#  ('have', 34),
#  ('so', 33)]

# %%
fdist1.plot(50, cumulative= True)

# %%
from nltk.probability import ConditionalFreqDist

# %%
cfdist = ConditionalFreqDist((len(word), word) for word in text1)

# %%
cfdist[5]
# Out:
# FreqDist({'about': 45, 'going': 27, 'CoD4.': 16, 'Going': 15, 'after': 13, 'think': 13, 'great': 12, 'video': 10, 'first': 9, 'there': 9, ...})

# %%
cfdist[3]
# Out:
# FreqDist({'the': 316, 'for': 179, 'and': 165, 'url': 96, 'are': 45, 'new': 44, 'out': 43, "I'm": 35, 'get': 32, 'day': 32, ...})

# %% [markdown]
# #  lexical resource

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import nltk
entries = nltk.corpus.cmudict.entries()
print(entries)
len(entries)

# %%
for entry in entries[10:35]:
    print(entry)
# Out:
# ('aamodt', ['AA1', 'M', 'AH0', 'T'])
# ('aancor', ['AA1', 'N', 'K', 'AO2', 'R'])
# ('aardema', ['AA0', 'R', 'D', 'EH1', 'M', 'AH0'])
# ('aardvark', ['AA1', 'R', 'D', 'V', 'AA2', 'R', 'K'])
# ('aaron', ['EH1', 'R', 'AH0', 'N'])
# ("aaron's", ['EH1', 'R', 'AH0', 'N', 'Z'])
# ('aarons', ['EH1', 'R', 'AH0', 'N', 'Z'])
# ('aaronson', ['EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'])
# ('aaronson', ['AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'])
# ("aaronson's", ['EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z'])
# ("aaronson's", ['AA1', 'R', 'AH0', 'N', 'S', 'AH0', 'N', 'Z'])
# ('aarti', ['AA1', 'R', 'T', 'IY2'])
# ('aase', ['AA1', 'S'])
# ('aasen', ['AA1', 'S', 'AH0', 'N'])
# ('ab', ['AE1', 'B'])
# ('ab', ['EY1', 'B', 'IY1'])
# ('ababa', ['AH0', 'B', 'AA1', 'B', 'AH0'])
# ('ababa', ['AA1', 'B', 'AH0', 'B', 'AH0'])
# ('abacha', ['AE1', 'B', 'AH0', 'K', 'AH0'])
# ('aback', ['AH0', 'B', 'AE1', 'K'])
# ('abaco', ['AE1', 'B', 'AH0', 'K', 'OW2'])
# ('abacus', ['AE1', 'B', 'AH0', 'K', 'AH0', 'S'])
# ...

# %%
#benz is credited with the invention of the motorcar
#benz is credited with the invention of the automible

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets('motorcar')
# Out:
# [Synset('car.n.01')]

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
wn.synsets('medical')
# Out:
# [Synset('checkup.n.01'),
#  Synset('medical.a.01'),
#  Synset('medical.a.02'),
#  Synset('aesculapian.a.01')]

# %%
wn.synset('checkup.n.01').lemma_names()
# Out:
# ['checkup',
#  'medical_checkup',
#  'medical_examination',
#  'medical_exam',
#  'medical',
#  'health_check']

# %% [markdown]
# # Pipe line

# %%
import nltk

# %%
texts = ['''Hierarchical clustering algorithms fall into 2 categories: 
top-down or bottom-up. Bottom-up algorithms treat each data point as 
a single cluster at the outset and then successively merge (or 
agglomerate) pairs of clusters until all clusters have been merged
into a single cluster that contains all data points. Bottom-up 
hierarchical clustering is therefore called hierarchical agglomerative
clustering or HAC. This hierarchy of clusters is represented as a tree
(or dendrogram). The root of the tree is the unique cluster that
gathers all the samples, the leaves being the clusters with only one
sample. Check out the graphic below for an illustration before moving
on to the algorithm steps
''']

# %%
for text in texts:
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged_words = nltk.pos_tag(words)
        ne_tagged_words = nltk.ne_chunk(tagged_words)
        print(ne_tagged_words)
# Out:
# (S
#   Hierarchical/JJ
#   clustering/VBG
#   algorithms/JJ
#   fall/NN
#   into/IN
#   2/CD
#   categories/NNS
#   :/:
#   top-down/JJ
#   or/CC
#   bottom-up/NN
#   ./.)
# (S
#   Bottom-up/NNP
#   algorithms/JJ
#   treat/NN
#   each/DT
#   data/NN
#   point/NN
#   as/IN
#   a/DT
#   single/JJ
#   cluster/NN
#   at/IN
#   the/DT
#   outset/NN
#   and/CC
#   then/RB
#   successively/RB
#   merge/NN
#   (/(
#   or/CC
#   agglomerate/NN
#   )/)
#   pairs/NN
#   of/IN
#   clusters/NNS
#   until/IN
#   all/DT
#   clusters/NNS
#   have/VBP
#   been/VBN
#   merged/VBN
#   into/IN
#   a/DT
#   single/JJ
#   cluster/NN
#   that/WDT
#   contains/VBZ
#   all/DT
#   data/NN
#   points/NNS
#   ./.)
# (S
#   Bottom-up/NNP
#   hierarchical/JJ
#   clustering/NN
#   is/VBZ
#   therefore/RB
#   called/JJ
#   hierarchical/JJ
#   agglomerative/NN
#   clustering/NN
#   or/CC
#   (ORGANIZATION HAC/NNP)
#   ./.)
# (S
#   This/DT
#   hierarchy/NN
#   of/IN
#   clusters/NNS
#   is/VBZ
#   represented/VBN
# ...

# %% [markdown]
# # Tokenizer

# %%
import nltk

# %%
text = 'My name is ravi. i am from vizag'

# %%
sent_text = nltk.sent_tokenize(text)
print(sent_text)
# Out:
# ['My name is ravi.', 'i am from vizag']

# %%
word_text = nltk.word_tokenize(text)
print(word_text)
# Out:
# ['My', 'name', 'is', 'ravi', '.', 'i', 'am', 'from', 'vizag']

# %%
for sentence in sent_text:
    tokenized_text = nltk.word_tokenize(sentence)
    print(tokenized_text)
# Out:
# ['My', 'name', 'is', 'ravi', '.']
# ['i', 'am', 'from', 'vizag']

# %%
from nltk.tokenize import TweetTokenizer
text = 'That party was soooo fun! :D #superfun'
tknzr = TweetTokenizer()
tknzr.tokenize(text)
# Out:
# ['That', 'party', 'was', 'soooo', 'fun', '!', ':D', '#superfun']

# %% [markdown]
# # Regual expressions

# %%
import nltk
from nltk.tag import pos_tag
ex = 'The big yellow bird flow over my house'

# %%
def preprocess(sent):
    sent  = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(ex)
sent
# Out:
# [('The', 'DT'),
#  ('big', 'JJ'),
#  ('yellow', 'JJ'),
#  ('bird', 'NN'),
#  ('flow', 'NN'),
#  ('over', 'IN'),
#  ('my', 'PRP$'),
#  ('house', 'NN')]

# %%
ex1 = 'I am persuing masters in International institute of Information Technology hyderabad'
sent1 = preprocess(ex1)
sent1
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('persuing', 'VBG'),
#  ('masters', 'NNS'),
#  ('in', 'IN'),
#  ('International', 'NNP'),
#  ('institute', 'NN'),
#  ('of', 'IN'),
#  ('Information', 'NNP'),
#  ('Technology', 'NNP'),
#  ('hyderabad', 'NN')]

# %%
np_rule = "NP:{<DT>?<JJ>*<NN>}"

# %%
reg_rule = r"""
    NP:{<DT|PRP\$>?<JJ>*<NN>}
       {<NNP>+}
       """

# %%
cp = nltk.RegexpParser(reg_rule)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (NP The/DT big/JJ yellow/JJ bird/NN)
#   (NP flow/NN)
#   over/IN
#   (NP my/PRP$ house/NN))

# %%
cp = nltk.RegexpParser(np_rule)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (NP The/DT big/JJ yellow/JJ bird/NN)
#   (NP flow/NN)
#   over/IN
#   my/PRP$
#   (NP house/NN))

# %%
np_rule1 = "NP:{<DT>?<JJ>*<NN>}"

# %%
cp1 = nltk.RegexpParser(np_rule1)
cs1 = cp1.parse(sent1)
print(cs1)
# Out:
# (S
#   I/PRP
#   am/VBP
#   persuing/VBG
#   masters/NNS
#   in/IN
#   International/NNP
#   (NP institute/NN)
#   of/IN
#   Information/NNP
#   Technology/NNP
#   (NP hyderabad/NN))

# %% [markdown]
# # NaiveBayesClassifier

# %% [markdown]
# # binary classification

# %%
import nltk

# %%
def gender_features(word):
    return {'last_letter': word[-1]}

# %%
gender_features('katie')
# Out:
# {'last_letter': 'e'}

# %%
from nltk.corpus import names
labeled_names = ([(name, 'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])
labeled_names
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male'),
#  ('Abdullah', 'male'),
#  ('Abe', 'male'),
#  ('Abel', 'male'),
#  ('Abelard', 'male'),
#  ('Abner', 'male'),
#  ('Abraham', 'male'),
#  ('Abram', 'male'),
#  ('Ace', 'male'),
#  ('Adair', 'male'),
#  ('Adam', 'male'),
#  ('Adams', 'male'),
#  ('Addie', 'male'),
#  ('Adger', 'male'),
#  ('Aditya', 'male'),
#  ('Adlai', 'male'),
#  ('Adnan', 'male'),
#  ('Adolf', 'male'),
#  ('Adolfo', 'male'),
#  ('Adolph', 'male'),
#  ('Adolphe', 'male'),
#  ('Adolpho', 'male'),
#  ('Adolphus', 'male'),
#  ('Adrian', 'male'),
#  ('Adrick', 'male'),
#  ('Adrien', 'male'),
#  ('Agamemnon', 'male'),
#  ('Aguinaldo', 'male'),
#  ('Aguste', 'male'),
#  ('Agustin', 'male'),
#  ('Aharon', 'male'),
#  ('Ahmad', 'male'),
#  ('Ahmed', 'male'),
#  ('Ahmet', 'male'),
#  ('Ajai', 'male'),
# ...

# %%
import random
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Ardys', 'female'),
#  ('Jimbo', 'male'),
#  ('Jef', 'male'),
#  ('Manya', 'female'),
#  ('Dorri', 'female'),
#  ('Aubree', 'female'),
#  ('Bianka', 'female'),
#  ('Jobey', 'female'),
#  ('Steffi', 'female'),
#  ('Fae', 'female'),
#  ('Willi', 'male'),
#  ('Antonietta', 'female'),
#  ('Linette', 'female'),
#  ('Rhianon', 'female'),
#  ('Winnifred', 'female'),
#  ('Gerri', 'female'),
#  ('Jessamine', 'female'),
#  ('Cooper', 'male'),
#  ('Brunhilda', 'female'),
#  ('Wilow', 'female'),
#  ('Geoffry', 'male'),
#  ('Bree', 'female'),
#  ('Daniela', 'female'),
#  ('Shoshie', 'female'),
#  ('Jock', 'male'),
#  ('Georgeta', 'female'),
#  ('Nelsen', 'male'),
#  ('Rosalyn', 'female'),
#  ('Roy', 'male'),
#  ('Fernanda', 'female'),
#  ('Gabrielle', 'female'),
#  ('Osborne', 'male'),
#  ('Jocelyn', 'female'),
#  ('Jemmie', 'female'),
#  ('Annmarie', 'female'),
#  ('Maud', 'female'),
#  ('Giffard', 'male'),
#  ('Doro', 'female'),
#  ('Jo-Anne', 'female'),
#  ('Nicky', 'female'),
# ...

# %%
featuresets = [(gender_features(n),gender) for (n, gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'w'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
# ...

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('David'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Michelle'))
# Out:
# 'female'

# %%
classifier.classify(gender_features('tej'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.756

# %% [markdown]
# # NaiveBayes mutiple Classifier

# %%
from nltk.tokenize.casual import EMOTICON_RE

# %%
def age_feature(message):
#     print(message)
    emoticon = EMOTICON_RE.findall(' '.join(message))
#     print(emoticon)
    length = len(message)
    if not emoticon:
        emoticon =0
    else:
        emoticon =1
    return {'Emoticons':emoticon,'Length':length}

# %%
from nltk.corpus import nps_chat
chatroom20 = nps_chat.posts('10-19-20s_706posts.xml')
chatroom30 = nps_chat.posts('10-19-30s_705posts.xml')
chatroom40 = nps_chat.posts('10-19-40s_686posts.xml')
print(chatroom20)
print(chatroom30)
print(chatroom40)
# Out:
# [['now', 'im', 'left', 'with', 'this', 'gay', 'name'], [':P'], ...]
# [['U11', 'lol'], ['lol', 'U11'], ['wb', 'U9'], ...]
# [['hi', 'U23'], ['love', 'me', 'like', 'a', 'bomb', 'baby', 'come', 'on', 'get', 'it', 'on'], ...]

# %%
# [(post,'20s') for post in chatroom20]

# %%
chatroom40[100]
# Out:
# ['u', 'evil', 'twin', 'left', 'U27']

# %%
labeled_chats = ([(post,'20s') for post in chatroom20]+[(post,'30s') for post in chatroom30]+[(post,'40s') for post in chatroom40])

# %%
labeled_chats[90]
# Out:
# (['JOIN'], '20s')

# %%
# [(n) for (n, age) in labeled_chats]

# %%
import random
random.shuffle(labeled_chats)
featureset = [(age_feature(n),age) for (n, age) in labeled_chats]
train_Set,test_set = featureset[500:], featureset[:500]

# %%
train_Set
# Out:
# [({'Emoticons': 0, 'Length': 2}, '30s'),
#  ({'Emoticons': 0, 'Length': 4}, '40s'),
#  ({'Emoticons': 0, 'Length': 2}, '30s'),
#  ({'Emoticons': 0, 'Length': 4}, '20s'),
#  ({'Emoticons': 0, 'Length': 3}, '40s'),
#  ({'Emoticons': 0, 'Length': 15}, '40s'),
#  ({'Emoticons': 0, 'Length': 1}, '20s'),
#  ({'Emoticons': 0, 'Length': 2}, '40s'),
#  ({'Emoticons': 0, 'Length': 3}, '40s'),
#  ({'Emoticons': 0, 'Length': 3}, '20s'),
#  ({'Emoticons': 0, 'Length': 6}, '20s'),
#  ({'Emoticons': 0, 'Length': 6}, '20s'),
#  ({'Emoticons': 1, 'Length': 6}, '20s'),
#  ({'Emoticons': 0, 'Length': 2}, '40s'),
#  ({'Emoticons': 0, 'Length': 5}, '20s'),
#  ({'Emoticons': 0, 'Length': 1}, '20s'),
#  ({'Emoticons': 0, 'Length': 10}, '20s'),
#  ({'Emoticons': 0, 'Length': 2}, '20s'),
#  ({'Emoticons': 0, 'Length': 6}, '30s'),
#  ({'Emoticons': 0, 'Length': 1}, '30s'),
#  ({'Emoticons': 0, 'Length': 1}, '20s'),
#  ({'Emoticons': 0, 'Length': 2}, '20s'),
#  ({'Emoticons': 0, 'Length': 9}, '20s'),
# ...

# %%
classifier = nltk.NaiveBayesClassifier.train(train_Set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.4

# %% [markdown]
# # movie reviews classification

# %%
import nltk
from nltk.corpus import movie_reviews
import random
# print(movie_reviews.categories())
documents = [(list(movie_reviews.words(fileid)),category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]
random.shuffle(documents)
print(documents[0])
# Out:
# (['i', "'", 'm', 'currently', 'accepting', 'all', 'future', 'names', 'for', 'drew', 'barrymore', 'characters', '.', 'in', '_the', 'wedding', 'singer_', ',', 'she', 'was', 'julia', 'gulia', '.', 'in', '_never', 'been', 'kissed_', ',', 'she', "'", 's', 'josie', 'grossie', '.', 'future', 'db', 'character', 'names', 'include', ':', 'janet', 'granite', ',', 'janey', 'grainy', ',', 'and', 'for', 'that', 'nc', '-', '17', 'project', 'in', 'the', 'works', ',', 'jo', '-', 'jo', '.', '.', '.', 'aw', 'forget', 'it', '.', 'i', "'", 'll', 'stick', 'to', 'my', 'day', 'job', '.', 'this', 'is', 'a', 'teen', 'movie', ',', 'all', 'right', ',', 'except', 'the', 'main', 'characters', 'aren', "'", 't', 'teens', '.', 'drew', 'barrymore', 'is', 'a', 'copy', 'editor', 'at', 'the', 'chicago', 'sun', 'times', 'who', 'gets', 'her', 'big', 'break', 'as', 'a', 'reporter', ',', 'only', 'it', "'", 's', 'very', 'clear', 'from', 'the', 'onset', 'that', 'she', 'lacks', 'the', 'toughness', 'and', 'the', 'pushy', 'extra
# ...

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
# print(all_words[4])
word_features = list(all_words)[:2500]
# word_features

# %%
def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
print(movie_reviews.words('pos/cv957_8737.txt'))
# Out:
# ['capsule', ':', 'the', 'best', 'place', 'to', 'start', ...]

# %%
print(document_features(movie_reviews.words('pos/cv957_8737.txt')))
# Out:
# {'contains(,)': True, 'contains(the)': True, 'contains(.)': True, 'contains(a)': True, 'contains(and)': True, 'contains(of)': True, 'contains(to)': True, "contains(')": True, 'contains(is)': True, 'contains(in)': True, 'contains(s)': True, 'contains(")': True, 'contains(it)': True, 'contains(that)': True, 'contains(-)': True, 'contains())': True, 'contains(()': True, 'contains(as)': True, 'contains(with)': True, 'contains(for)': True, 'contains(his)': True, 'contains(this)': True, 'contains(film)': False, 'contains(i)': False, 'contains(he)': True, 'contains(but)': True, 'contains(on)': True, 'contains(are)': True, 'contains(t)': False, 'contains(by)': True, 'contains(be)': True, 'contains(one)': True, 'contains(movie)': True, 'contains(an)': True, 'contains(who)': True, 'contains(not)': True, 'contains(you)': True, 'contains(from)': True, 'contains(at)': False, 'contains(was)': False, 'contains(have)': True, 'contains(they)': True, 'contains(has)': True, 'contains(her)': False, 'con
# ...

# %%
from sklearn.model_selection import train_test_split
featuresets = [(document_features(d),c) for (d,c) in documents]
# print(featuresets)
train_set, test_set = train_test_split(featuresets, test_size=0.5)
# print(train_set[0])
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.794

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#    contains(outstanding) = True              pos : neg    =     23.1 : 1.0
#        contains(freedom) = True              pos : neg    =     12.4 : 1.0
#           contains(lame) = True              neg : pos    =      9.7 : 1.0
#     contains(ridiculous) = True              neg : pos    =      8.2 : 1.0
#          contains(snake) = True              neg : pos    =      7.3 : 1.0

# %% [markdown]
# # speech recognition system

# %%
import speech_recognition as ss
# import pyaudio
r = ss.Recognizer()
with ss.Microphone() as source:
    print('say something')
    print('hhbhbh')
    audio = r.listen(source)

# %%
try:
    print('google speech recognition thinks that you said:' + r.recognize_google(audio))
except sr.UnknownValueError:
    print('google speech recognition could not understand audio')
except sr.RequestError as e:
    print('could not request results from google speech recognition services;{0}'.format(e))

# %% [markdown]
# # chunk sets
#
# https://towardsdatascience.com/chunking-in-nlp-decoded-b4a71b2b4e24
# I’ve used the `conll2000` corpus for training chunker. conll2000 corpus defines the chunks using IOB tags.
# It specifies where the chunk begins and ends, along with its types.
# A POS tagger can be trained on these IOB tags
# The chunk tags use the IOB format.
# IOB : Inside,Outside,Beginning
# B- prefix before a tag indicates, it’s the beginning of a chunk
# I- prefix indicates that it’s inside a chunk
# O- tag indicates the token doesn’t belong to any chunk
#
#
# tree2conlltags,conlltags2tree are chunking utility functions.
# → `tree2conlltags`, to get triples of (word, tag, chunk tags for each token). These tuples are then finally used to train a tagger and it learns IOB tags for POS tags.
# → `conlltags2tree` to generate a parse tree from these token triples
# Conlltags2tree() is reversal of tree2conlltags().We’ll be using these functions to train our parser
#
#
# What is tagger?
# It reads text and assigns a POS tag to each word. (word, tag)
# Unigram tagger: For determining the POS, It only uses a single word. (single word context-based tagger)
# The UnigramTagger, BigramTagger, and TrigramTagger are classes that inherit from the base class NGramTagger, which itself inherits from the ContextTagger class, which inherits from the SequentialBackoffTagger class
# We will now define a class NGramTagChunker that will take in tagged sentences as training input, get their (word, POS tag, chunk tag)WTC triples and train a BigramTagger with a UnigramTagger as the backoff tagger.
# We will also define a parse() function to perform shallow parsing on a new sentence.

# %%
import nltk
nltk.download('conll2000')
from nltk.corpus import conll2000
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\raviteja\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!

# %%
from nltk.corpus import conll2000
chunked_sent = conll2000.chunked_sents()[0]
print(chunked_sent)
# Out:
# (S
#   (NP Confidence/NN)
#   (PP in/IN)
#   (NP the/DT pound/NN)
#   (VP is/VBZ widely/RB expected/VBN to/TO take/VB)
#   (NP another/DT sharp/JJ dive/NN)
#   if/IN
#   (NP trade/NN figures/NNS)
#   (PP for/IN)
#   (NP September/NNP)
#   ,/,
#   due/JJ
#   (PP for/IN)
#   (NP release/NN)
#   (NP tomorrow/NN)
#   ,/,
#   (VP fail/VB to/TO show/VB)
#   (NP a/DT substantial/JJ improvement/NN)
#   (PP from/IN)
#   (NP July/NNP and/CC August/NNP)
#   (NP 's/POS near-record/JJ deficits/NNS)
#   ./.)

# %%
from nltk.chunk import tree2conlltags,conlltags2tree
iob_tagged = tree2conlltags(chunked_sent)
print(iob_tagged)
# Out:
# [('Confidence', 'NN', 'B-NP'), ('in', 'IN', 'B-PP'), ('the', 'DT', 'B-NP'), ('pound', 'NN', 'I-NP'), ('is', 'VBZ', 'B-VP'), ('widely', 'RB', 'I-VP'), ('expected', 'VBN', 'I-VP'), ('to', 'TO', 'I-VP'), ('take', 'VB', 'I-VP'), ('another', 'DT', 'B-NP'), ('sharp', 'JJ', 'I-NP'), ('dive', 'NN', 'I-NP'), ('if', 'IN', 'O'), ('trade', 'NN', 'B-NP'), ('figures', 'NNS', 'I-NP'), ('for', 'IN', 'B-PP'), ('September', 'NNP', 'B-NP'), (',', ',', 'O'), ('due', 'JJ', 'O'), ('for', 'IN', 'B-PP'), ('release', 'NN', 'B-NP'), ('tomorrow', 'NN', 'B-NP'), (',', ',', 'O'), ('fail', 'VB', 'B-VP'), ('to', 'TO', 'I-VP'), ('show', 'VB', 'I-VP'), ('a', 'DT', 'B-NP'), ('substantial', 'JJ', 'I-NP'), ('improvement', 'NN', 'I-NP'), ('from', 'IN', 'B-PP'), ('July', 'NNP', 'B-NP'), ('and', 'CC', 'I-NP'), ('August', 'NNP', 'I-NP'), ("'s", 'POS', 'B-NP'), ('near-record', 'JJ', 'I-NP'), ('deficits', 'NNS', 'I-NP'), ('.', '.', 'O')]

# %%
print(len(conll2000.chunked_sents()))
print(len(conll2000.chunked_words()))
# Out:
# 10948
# 166433

# %%
import random
from sklearn.model_selection import train_test_split
shuffled_conll_sents = list(conll2000.chunked_sents())
train_set,test_set = train_test_split(shuffled_conll_sents, test_size = 0.1)

# %%
from nltk import ChunkParserI, TrigramTagger

# %%
class TrigramChunkParser(ChunkParserI):
    def __init__(self, train_set):
        train_data = [[(pos_tag, chunk_tag) for word, pos_tag, chunk_tag in tree2conlltags(sent)]
                       for sent in train_set]
        self.tagger = TrigramTagger(train_data)
    def parse(self, sentence):
        pos_tags = [pos for word, pos in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        conlltags = [(word, pos_tag, chunk_tag)
                    for ((word, pos_tag),(pos_tag, chunk_tag)) in zip(sentence, tagged_pos_tags)]
        return conlltags2tree(conlltags)

# %%
trigram_chunker = TrigramChunkParser(train_set)

# %%
print(trigram_chunker.evaluate(test_set))
# Out:
# ChunkParse score:
#     IOB Accuracy:  87.6%%
#     Precision:     80.1%%
#     Recall:        84.2%%
#     F-Measure:     82.1%%
